# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_matches = './data/raw_matches.csv'
raw_winners = './data/raw_winners.csv'
results = './data/results.csv'
fifa_rankings = './data/fifa_rankings.csv'
world_cup_2018 = './data/world_cup_2018.csv'
schedule = './data/fifa-world-cup-2018_schedule.csv'

# %%
teams_2018 = [ i for i in set().union(sc['Home Team'], sc['Away Team']) if ('Winner' not in i and 'Runner' not in i and 'announced' not in i)]
teams_2018
# Out:
# ['Egypt',
#  'Senegal',
#  'Russia',
#  'Tunisia',
#  'Colombia',
#  'Denmark',
#  'France',
#  'Nigeria',
#  'Switzerland',
#  'Spain',
#  'Poland',
#  'Iceland',
#  'Portugal',
#  'Brazil',
#  'Serbia',
#  'Morocco',
#  'Belgium',
#  'Argentina',
#  'Japan',
#  'Panama',
#  'Iran',
#  'Uruguay',
#  'Croatia',
#  'Germany',
#  'England',
#  'Australia',
#  'Sweden',
#  'Peru',
#  'Costa Rica',
#  'Saudi Arabia',
#  'Mexico',
#  'Korea Republic']

# %%
rm = pd.read_csv(raw_matches)
rm.head()
# Out:
#    id  year       team1  score1  score2        team2
# 0   0  1950      Brazil       4       0       Mexico
# 1   1  1950  Yugoslavia       3       0  Switzerland
# 2   2  1950      Brazil       2       2  Switzerland
# 3   3  1950  Yugoslavia       4       1       Mexico
# 4   4  1950      Brazil       2       0   Yugoslavia

# %%
rw = pd.read_csv(raw_winners)
rw.head()
rw.groupby('team').nunique().sort_values('year')
# Out:
#                 year  position  team
# team
# Hungary            1         1     1
# Turkey             1         1     1
# Soviet Union       1         1     1
# South Korea        1         1     1
# Czechoslovakia     1         1     1
# Croatia            1         1     1
# Yugoslavia         1         1     1
# Bulgaria           1         1     1
# Austria            1         1     1
# Belgium            1         1     1
# Chile              1         1     1
# Spain              2         2     1
# Poland             2         1     1
# Portugal           2         2     1
# England            2         2     1
# Germany            3         2     1
# Sweden             3         2     1
# Argentina          3         2     1
# Uruguay            4         2     1
# Netherlands        4         2     1
# France             5         4     1
# Italy              6         4     1
# West Germany       8         4     1
# Brazil             9         4     1

# %%
rs = pd.read_csv(results)
rs.head()
rs['year'] = [int(d[0]) for d in rs['date'].str.split('-')]
rs['month'] = [int(d[1]) for d in rs['date'].str.split('-')]
rs['day'] = [int(d[2]) for d in rs['date'].str.split('-')]
rs = rs.drop('date', axis=1)
rs = rs.drop(rs[rs.year < 1950].index)
rs = rs[rs.home_team.isin(teams_2018) & rs.away_team.isin(teams_2018)]
rs
# Out:
#             home_team       away_team  home_score  away_score  \
# 3014          Croatia          Serbia           4           1
# 3026            Spain        Portugal           5           1
# 3029         Portugal           Spain           2           2
# 3038           Brazil         Uruguay           3           4
# 3043           Brazil         Uruguay           3           2
# 3045         Portugal         England           3           5
# 3046          Belgium         England           1           4
# 3054          Belgium          France           4           1
# 3062           Brazil          Mexico           4           0
# 3069           Brazil     Switzerland           2           2
# 3078          England           Spain           0           1
# 3080           Mexico     Switzerland           1           2
# 3082           Brazil          Sweden           7           1
# 3083            Spain         Uruguay           2           2
# ...

# %%
sc = pd.read_csv(schedule)
sc.head()
# Out:
#   Round Number              Date                  Location Home Team  \
# 0            1  14/06/2018 18:00  Luzhniki Stadium, Moscow    Russia
# 1            1  15/06/2018 15:00      Ekaterinburg Stadium     Egypt
# 2            1  15/06/2018 18:00  Saint Petersburg Stadium   Morocco
# 3            1  15/06/2018 21:00      Fisht Stadium, Sochi  Portugal
# 4            1  16/06/2018 13:00               Kazan Arena    France
#
#       Away Team    Group  Result
# 0  Saudi Arabia  Group A     NaN
# 1       Uruguay  Group A     NaN
# 2          Iran  Group B     NaN
# 3         Spain  Group B     NaN
# 4     Australia  Group C     NaN

# %%
match = ['Portugal', 'Spain']
rm.loc[rm.team1.isin(match) | rm.team2.isin(match)]
rs.loc[rs.home_team.isin(match) & rs.away_team.isin(match)]
# Out:
#       home_team away_team  home_score  away_score  \
# 3026      Spain  Portugal           5           1
# 3029   Portugal     Spain           2           2
# 3900   Portugal     Spain           3           1
# 4254      Spain  Portugal           1           0
# 5658   Portugal     Spain           2           1
# 10910     Spain  Portugal           1           1
# 11724  Portugal     Spain           2           0
# 12989  Portugal     Spain           1           1
# 16222     Spain  Portugal           1           1
# 16681  Portugal     Spain           0           0
# 17978     Spain  Portugal           2           2
# 24361     Spain  Portugal           1           1
# 25560  Portugal     Spain           0           3
# 26382     Spain  Portugal           0           1
# 31728     Spain  Portugal           1           0
# 32148  Portugal     Spain           4           0
# 33725  Portugal     Spain           0           0
#
# ...

# %%
predict = sc.drop(['Round Number', 'Location', 'Date', 'Group', 'Result'], axis=1)
predict = predict.rename(columns={'Home Team': 'home_team', 'Away Team': 'away_team'})
#predict['home_score_pred'] = rs.loc[rs.home_team.isin(match) & rs.away_team.isin(match), 'home_score'].mean()
#predict['away_score_pred'] = rs.loc[rs.home_team.isin(match) & rs.away_team.isin(match), 'away_score'].mean()

for i in range(len(predict)):
    match = predict.iloc[i].values
    predict.loc[i, 'home_score_pred'] = rs.loc[rs.home_team.isin(match) & rs.away_team.isin(match), 'home_score'].mean()
    predict.loc[i, 'away_score_pred'] = rs.loc[rs.home_team.isin(match) & rs.away_team.isin(match), 'away_score'].mean()
    
predict
# Out:
#           home_team            away_team  home_score_pred  away_score_pred
# 0            Russia         Saudi Arabia         4.000000         2.000000
# 1             Egypt              Uruguay         0.000000         2.000000
# 2           Morocco                 Iran         1.000000         1.000000
# 3          Portugal                Spain         1.529412         0.882353
# 4            France            Australia         2.000000         0.500000
# 5         Argentina              Iceland              NaN              NaN
# 6              Peru              Denmark              NaN              NaN
# 7           Croatia              Nigeria              NaN              NaN
# 8        Costa Rica               Serbia              NaN              NaN
# 9           Germany               Mexico         2.363636         0.727273
# 10           Brazil          Switzerland         1.250000         1.000000
# ...
